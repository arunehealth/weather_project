# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##### reading the dataset

# %%
df = pd.read_csv("C:\\Users\\Arunakiry Natarajan\\Desktop\\DataScience\\DataSets\\weather_project\\weather_train.csv")

# %%
df. head(2)
# Out:
#          Date        ACME        ADAX        ALTU        APAC        ARNE  \
# 0  19940101.0  12384900.0  11930700.0  12116700.0  12301200.0  10706100.0
# 1  19940102.0  11908500.0   9778500.0  10862700.0  11666400.0   8062500.0
#
#          BEAV        BESS        BIXB        BLAC     ...            VINI  \
# 0  10116900.0  11487900.0  11182800.0  10848300.0     ...      10771800.0
# 1   9262800.0   9235200.0   3963300.0   3318300.0     ...       4314300.0
#
#          WASH        WATO        WAUR        WEAT        WEST        WILB  \
# 0  12116400.0  11308800.0  12361800.0  11331600.0  10644300.0  11715600.0
# 1  10733400.0   9154800.0  12041400.0   9168300.0   4082700.0   9228000.0
#
#          WIST        WOOD        WYNO
# 0  11241000.0  10490100.0  10545300.0
# 1   5829900.0   7412100.0   3345300.0
#
# [2 rows x 99 columns]

# %%
df.shape
# Out:
# (5114, 99)

# %%
df.describe()
# Out:
#                Date          ACME          ADAX          ALTU          APAC  \
# count  5.113000e+03  5.113000e+03  5.113000e+03  5.113000e+03  5.113000e+03
# mean   2.000567e+07  1.687746e+07  1.623753e+07  1.711919e+07  1.701057e+07
# std    4.031286e+04  7.869606e+06  7.905850e+06  7.702989e+06  7.883455e+06
# min    1.994010e+07  1.200000e+04  5.100000e+05  9.000000e+02  3.300000e+03
# 25%    1.997070e+07  1.140420e+07  1.061100e+07  1.167450e+07  1.163700e+07
# 50%    2.000123e+07  1.694640e+07  1.629930e+07  1.707360e+07  1.706250e+07
# 75%    2.004070e+07  2.373480e+07  2.302740e+07  2.390370e+07  2.390940e+07
# max    2.007123e+07  3.134790e+07  3.122700e+07  3.141150e+07  3.161610e+07
#
#                ARNE          BEAV          BESS          BIXB          BLAC  \
# count  5.113000e+03  5.113000e+03  5.113000e+03  5.113000e+03  5.113000e+03
# mean   1.756017e+07  1.761214e+07  1.730407e+07  1.596963e+07  1.606171e+07
# ...

# %%
df.columns
# Out:
# Index(['Date', 'ACME', 'ADAX', 'ALTU', 'APAC', 'ARNE', 'BEAV', 'BESS', 'BIXB',
#        'BLAC', 'BOIS', 'BOWL', 'BREC', 'BRIS', 'BUFF', 'BURB', 'BURN', 'BUTL',
#        'BYAR', 'CAMA', 'CENT', 'CHAN', 'CHER', 'CHEY', 'CHIC', 'CLAY', 'CLOU',
#        'COOK', 'COPA', 'DURA', 'ELRE', 'ERIC', 'EUFA', 'FAIR', 'FORA', 'FREE',
#        'FTCB', 'GOOD', 'GUTH', 'HASK', 'HINT', 'HOBA', 'HOLL', 'HOOK', 'HUGO',
#        'IDAB', 'JAYX', 'KENT', 'KETC', 'LAHO', 'LANE', 'MADI', 'MANG', 'MARE',
#        'MAYR', 'MCAL', 'MEDF', 'MEDI', 'MIAM', 'MINC', 'MTHE', 'NEWK', 'NINN',
#        'NOWA', 'OILT', 'OKEM', 'OKMU', 'PAUL', 'PAWN', 'PERK', 'PRYO', 'PUTN',
#        'REDR', 'RETR', 'RING', 'SALL', 'SEIL', 'SHAW', 'SKIA', 'SLAP', 'SPEN',
#        'STIG', 'STIL', 'STUA', 'SULP', 'TAHL', 'TALI', 'TIPT', 'TISH', 'VINI',
#        'WASH', 'WATO', 'WAUR', 'WEAT', 'WEST', 'WILB', 'WIST', 'WOOD', 'WYNO'],
#       dtype='object')

# %% [markdown]
# ##### creatting monthly averages for each city

# %%
df.groupby('Date').groups.keys()
df_datemean = df.groupby('Date') ['ACME', 'ADAX', 'ALTU', 'APAC', 'ARNE', 'BEAV', 'BESS', 'BIXB',
       'BLAC', 'BOIS', 'BOWL', 'BREC', 'BRIS', 'BUFF', 'BURB', 'BURN', 'BUTL',
       'BYAR', 'CAMA', 'CENT', 'CHAN', 'CHER', 'CHEY', 'CHIC', 'CLAY', 'CLOU',
       'COOK', 'COPA', 'DURA', 'ELRE', 'ERIC', 'EUFA', 'FAIR', 'FORA', 'FREE',
       'FTCB', 'GOOD', 'GUTH', 'HASK', 'HINT', 'HOBA', 'HOLL', 'HOOK', 'HUGO',
       'IDAB', 'JAYX', 'KENT', 'KETC', 'LAHO', 'LANE', 'MADI', 'MANG', 'MARE',
       'MAYR', 'MCAL', 'MEDF', 'MEDI', 'MIAM', 'MINC', 'MTHE', 'NEWK', 'NINN',
       'NOWA', 'OILT', 'OKEM', 'OKMU', 'PAUL', 'PAWN', 'PERK', 'PRYO', 'PUTN',
       'REDR', 'RETR', 'RING', 'SALL', 'SEIL', 'SHAW', 'SKIA', 'SLAP', 'SPEN',
       'STIG', 'STIL', 'STUA', 'SULP', 'TAHL', 'TALI', 'TIPT', 'TISH', 'VINI',
       'WASH', 'WATO', 'WAUR', 'WEAT', 'WEST', 'WILB', 'WIST', 'WOOD', 'WYNO'].mean()

# %%
df_datemean.head()
# Out:
#                   ACME        ADAX        ALTU        APAC        ARNE  \
# Date
# 19940101.0  12384900.0  11930700.0  12116700.0  12301200.0  10706100.0
# 19940102.0  11908500.0   9778500.0  10862700.0  11666400.0   8062500.0
# 19940103.0  12470700.0   9771900.0  12627300.0  12782700.0  11618400.0
# 19940104.0  12725400.0   6466800.0  13065300.0  12817500.0  12134400.0
# 19940105.0  10894800.0  11545200.0   8060400.0  10379400.0   6918600.0
#
#                   BEAV        BESS        BIXB        BLAC        BOIS  \
# Date
# 19940101.0  10116900.0  11487900.0  11182800.0  10848300.0  10225200.0
# 19940102.0   9262800.0   9235200.0   3963300.0   3318300.0  11316600.0
# 19940103.0  10789800.0  11895900.0   4512600.0   5266500.0  11916000.0
# 19940104.0  11816700.0  12186600.0   3212700.0   8270100.0  11884200.0
# 19940105.0   9936300.0   6411300.0   9566100.0   8009400.0   9288900.0
#
#                ...            VINI        WASH        WATO        WAUR  \
# Date           ...
# ...

# %%
df_datemean.tail(2)
# Out:
#                   ACME        ADAX        ALTU        APAC        ARNE  \
# Date
# 20071227.0   1408500.0   1371000.0   1742400.0   1389300.0   1349400.0
# 20071228.0  10060800.0   6581700.0  12027300.0  11312100.0   9665100.0
# 20071229.0  11388000.0  11353800.0  11946900.0   9662400.0  10938300.0
# 20071230.0  12441000.0  11883300.0  12409200.0  12155400.0  11937600.0
# 20071231.0  12450300.0  12104100.0  12015600.0  12516600.0   8480100.0
#
#                   BEAV        BESS        BIXB        BLAC        BOIS  \
# Date
# 20071227.0   1466400.0   1245900.0   1674000.0    922500.0   1836900.0
# 20071228.0   7993800.0  11962200.0   9010500.0   5747700.0  12528000.0
# 20071229.0  11315100.0  11402400.0  10683300.0   8954400.0  12625200.0
# 20071230.0  12314100.0  12006000.0  11695800.0  10249500.0  12436800.0
# 20071231.0   9302400.0  11198100.0   9687300.0   9957900.0   6465000.0
#
#                ...            VINI        WASH        WATO        WAUR  \
# Date           ...
# ...

# %%
bins = (19940000.0,19950000.0,19960000.0,19970000.0,19980000.0)
df['binned'] = pd.cut(df['Date'],bins)

# %%
df.head()
# Out:
#          Date        ACME        ADAX        ALTU        APAC        ARNE  \
# 0  19940101.0  12384900.0  11930700.0  12116700.0  12301200.0  10706100.0
# 1  19940102.0  11908500.0   9778500.0  10862700.0  11666400.0   8062500.0
# 2  19940103.0  12470700.0   9771900.0  12627300.0  12782700.0  11618400.0
# 3  19940104.0  12725400.0   6466800.0  13065300.0  12817500.0  12134400.0
# 4  19940105.0  10894800.0  11545200.0   8060400.0  10379400.0   6918600.0
#
#          BEAV        BESS        BIXB        BLAC            ...             \
# 0  10116900.0  11487900.0  11182800.0  10848300.0            ...
# 1   9262800.0   9235200.0   3963300.0   3318300.0            ...
# 2  10789800.0  11895900.0   4512600.0   5266500.0            ...
# 3  11816700.0  12186600.0   3212700.0   8270100.0            ...
# 4   9936300.0   6411300.0   9566100.0   8009400.0            ...
#
#          WASH        WATO        WAUR        WEAT        WEST        WILB  \
# ...

# %%
sns.distplot(df_datemean['WAUR'])

# %%
plt.scatter(df["WAUR"], df["ACME"], df["ALTU"], c=df["Date"] ,alpha=0.5)
plt.title("Distribution of pickup latitude and longitude locations labeled by latitude bins")
plt.xlabel("Date")
plt.ylabel("WAUR")
plt.show()
